# %%
# Install the libraries needed
# ! pip install openpyxl

# %%
# load the datasets
import pandas as pd

csv_data = pd.read_csv("../../data/raw/finalalldata.csv")
excel_data = pd.read_excel("../../data/raw/Dataset_PowerBI.xlsx")

# %%
import json

with open("../../data/raw/d09eafb5-c273-4bad-ac09-d18ea064064b.json", "r") as file:
    json_data = json.load(file)

# %%
csv_data.sample(7)
# Out:
#                    uid  label  sex  age    bmi  smoke  location  rs10007052  \
# 461  BT1811250402LMSBE      1    1   68  14.30      1      5.31    2.792241
# 364         copdcase78      1    1   48  24.80      1      8.72    1.671000
# 151            case236      1    2   71  28.40      0      6.88    1.671000
# 18        copdcontrol5      0    1   31  22.84      0      4.63    1.671000
# 387         copdcase73      1    2   62  35.70      0      8.72    1.000000
# 334            case248      1    1   59  19.60      1      8.72    1.671000
# 448  BT1812290140HMSBS      0    2   64  25.20      0      5.31    2.792241
#
#      rs8192288   rs20541  rs12922394  rs2910164  rs161976  rs473892  rs159497  \
# 461   0.351293  0.448632      1.0000   1.416000     1.000  1.000000  1.445000
# 364   0.592700  1.000000      0.6506   1.416000     1.594  1.473000  2.088025
# 151   1.000000  1.000000      1.0000   1.416000     1.000  1.000000  1.000000
# ...

# %%
excel_data.sample(8)
# Out:
#       Patient ID  Gender  Age  Heigt(cm)  Height(in)  weight kg  weight (lb)  \
# 608          655  Female   89        164      64.452         51      112.404
# 247          294  Female   77        167      65.631         61      134.444
# 814          861  Female   78        167      65.631         73      160.892
# 332          379    Male   68        180      70.740         85      187.340
# 701          748    Male   81        172      67.596        113      249.052
# 105          152  Female   66        160      62.880         96      211.584
# 861          908  Female   80        166      65.238         74      163.096
# 1133        1180    Male   85        181      71.133         69      152.076
#
#             BMI Smoker    Comorbidity1  ... RR During vigorous exercise  \
# 608   19.022356    Yes             NaN  ...                          47
# 247   21.942126     No             NaN  ...                          50
# ...

# %%
json_data
# Out:
# {'accessLevel': 'restricted public',
#  'bureauCode': ['020:00'],
#  'contactPoint': {'fn': 'Kristen Rappazzo',
#   'hasEmail': 'mailto:rappazzo.kristen@epa.gov'},
# ...

# %% [markdown]
# ### Extract the relevent columns

# %%
csv_selected_cols = csv_data[["sex", "bmi", "age", "location","smoke"]]
excel_selected_cols = excel_data[["Heigt(cm)", "weight kg", "BMI"]]

# %%
csv_selected_cols.shape
# Out:
# (633, 5)
