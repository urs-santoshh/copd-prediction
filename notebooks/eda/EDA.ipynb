# %% [markdown]
# # COPD in Nepal
#
# ### Factors that lead to COPD
# 1. Biomass Fuel Exposure (Indore air pollution)
# 2. Tobacco smoking
# 3. Outdoor air pollution (Vehicle emission, industrial smoke, dust form constructions etc.)
# 4. Occupational exposure (People working in agriculture, manufacruring industries, construction etc.)
# 5. Genetic susceptibility
# 6. Respiratory infections in the childhood
# 7. Low awareness and health access
# 9. Climate and environmental factors

# %% [markdown]
# ### Signs and symptoms of COPD
# 1. Chronic cough
# 2. Shortness of breath (dyspnea)
# 3. Excess mucous productions (Sputum) (Phlegm)
# 4. Wheezing (high-pitched whistling sound made while breathing)
# 5. Fatigue and low energy
# 6. Chest tightness
# 7. Frequent resipratory infections
# 8. Cynosis (medical term for when your skin, lips or nails turn blue due to a lack of oxygen in your blood)
# 9. Unintended weight loss
# 10. Chronic bronchitis and emphysema symptoms
# 11. Frequent Falre-ups (Exacerbations)

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load data 
data = pd.read_csv("../../data/synthetic_COPD_data.csv")

# %%
# check the random sample of the data
data.sample(8)
# Out:
#      Age  Gender Smoking_Status  Biomass_Fuel_Exposure  Occupational_Exposure  \
# 872   42  Female          Never                      0                      1
# 783   40    Male          Never                      1                      0
# 138   36    Male        Current                      1                      1
# 282   58  Female        Current                      1                      1
# 779   43    Male        Current                      1                      1
# 166   76  Female        Current                      0                      1
# 385   77    Male          Never                      1                      1
# 179   31    Male        Current                      1                      0
#
#      Family_History_COPD    BMI    Location  Air_Pollution_Level  \
# 872                    1  27.29   Nepalgunj                  165
# 783                    0  32.00      Butwal                  127
# 138                    0  29.26      Butwal                   73
# 282                    0  28.69     Chitwan                   53
# 779                    1  32.43  Biratnagar                  299
# 166                    1  18.69      Dharan                   80
# 385                    1  33.50   Kathmandu                  155
# 179                    1  19.03    Lalitpur                  149
#
#      Respiratory_Infections_Childhood  COPD_Diagnosis
# 872                                 1               0
# 783                                 0               0
# 138                                 1               1
# 282                                 1               1
# 779                                 0               1
# 166                                 0               1
# 385                                 0               1
# 179                                 0               1

# %%
# set up a large plot for better visibility
plt.figure(figsize=(14, 8))

# %%
# shape of the data
data.shape
# Out:
# (1000, 11)

# %%
# information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1000 non-null   int64
#  1   Gender                            1000 non-null   object
#  2   Smoking_Status                    1000 non-null   object
#  3   Biomass_Fuel_Exposure             1000 non-null   int64
#  4   Occupational_Exposure             1000 non-null   int64
#  5   Family_History_COPD               1000 non-null   int64
#  6   BMI                               1000 non-null   float64
#  7   Location                          1000 non-null   object
#  8   Air_Pollution_Level               1000 non-null   int64
#  9   Respiratory_Infections_Childhood  1000 non-null   int64
#  10  COPD_Diagnosis                    1000 non-null   int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 86.1+ KB

# %%
# description of numerical features
data.describe()
# Out:
#                Age  Biomass_Fuel_Exposure  Occupational_Exposure  \
# count  1000.000000            1000.000000            1000.000000
# mean     55.033000               0.494000               0.517000
# std      15.003233               0.500214               0.499961
# min      30.000000               0.000000               0.000000
# 25%      42.000000               0.000000               0.000000
# 50%      55.000000               0.000000               1.000000
# 75%      68.250000               1.000000               1.000000
# max      80.000000               1.000000               1.000000
#
#        Family_History_COPD          BMI  Air_Pollution_Level  \
# count          1000.000000  1000.000000          1000.000000
# mean              0.504000    26.682860           136.184000
# std               0.500234     4.797422            66.517191
# min               0.000000    18.510000            50.000000
# 25%               0.000000    22.587500            84.000000
# 50%               1.000000    26.440000           121.000000
# 75%               1.000000    30.662500           171.250000
# max               1.000000    35.000000           300.000000
#
#        Respiratory_Infections_Childhood  COPD_Diagnosis
# count                       1000.000000      1000.00000
# mean                           0.486000         0.31700
# std                            0.500054         0.46554
# min                            0.000000         0.00000
# 25%                            0.000000         0.00000
# 50%                            0.000000         0.00000
# 75%                            1.000000         1.00000
# max                            1.000000         1.00000

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### i. Numerical features

# %%
# what is the age distribution in my data
sns.histplot(data=data["Age"], bins=10, kde=True, color="blue")
plt.title("Age distribution")
plt.show()
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# BMI distribution
sns.histplot(data=data["BMI"], bins=10, kde=True, color="Green")
plt.title("BMI distribution")
plt.show()
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# #### ii. Categorical features

# %%
# gender distrubution
sns.countplot(x = "Gender", data=data, palette="viridis")
plt.title("Gender distribution")
plt.show()

# %%
# smoking status
sns.countplot(x = "Smoking_Status", data=data, palette="viridis")
plt.title("Smoking status")
plt.show()

# %% [markdown]
# ### Bivariate anlaysis

# %%
plt.figure(figsize=(14,10))

# %%
# Age vs COPD diagnosis
sns.boxenplot(x = "COPD_Diagnosis",y="Age", data=data, palette="coolwarm")
plt.title("Age vs COPD diagnosis")
plt.show()
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# BMI vs COPD diagnosis
sns.boxenplot(x = "COPD_Diagnosis", y = "BMI", data = data, palette="viridis")
plt.title("BMI vs COPD diagnosis")
plt.show()
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Smoking status vs COPD diagnosis
sns.countplot(x = "COPD_Diagnosis", hue="Smoking_Status", data = data, palette = "viridis")
plt.title("Count plot of COPD diagnosis")
plt.show()

# %%
# gender vs COPD diagnosis
sns.boxenplot(x = "COPD_Diagnosis", y = "Gender", data = data, palette="viridis")
plt.title("Gender vs COPD diagnosis")
plt.show()
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Multivariate analysis

# %%
# pairplot
sns.pairplot(data = data, hue="COPD_Diagnosis", diag_kind="kde", palette="Set1")
plt.title("Pair plot")
plt.show()
# Out:
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\DELL\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# correlation matrix
data_corr = data[["Age", "Biomass_Fuel_Exposure", "Occupational_Exposure", "Family_History_COPD", "BMI", "Air_Pollution_Level", "COPD_Diagnosis"]]
corr = data_corr.corr()

# %%
# correraltion heatmap
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
